# %%
from enum import Enum
from dataclasses import dataclass
from typing import Optional, Dict
from datetime import datetime
import requests

# %%
class QuoteAsset(Enum):
    USD = "USD"


class Status(Enum):
    CLOSE_ONLY = "CLOSE_ONLY"
    ONLINE = "ONLINE"


class TypeEnum(Enum):
    PERPETUAL = "PERPETUAL"


@dataclass
class Market:
    trades24_h: Optional[int] = None
    incremental_position_size: Optional[int] = None
    max_position_size: Optional[int] = None
    baseline_position_size: Optional[int] = None
    market: Optional[str] = None
    status: Optional[Status] = None
    base_asset: Optional[str] = None
    quote_asset: Optional[QuoteAsset] = None
    step_size: Optional[str] = None
    tick_size: Optional[str] = None
    index_price: Optional[str] = None
    oracle_price: Optional[str] = None
    price_change24_h: Optional[str] = None
    next_funding_rate: Optional[str] = None
    next_funding_at: Optional[datetime] = None
    min_order_size: Optional[str] = None
    type: Optional[TypeEnum] = None
    initial_margin_fraction: Optional[str] = None
    maintenance_margin_fraction: Optional[str] = None
    volume24_h: Optional[str] = None
    open_interest: Optional[str] = None
    incremental_initial_margin_fraction: Optional[str] = None
    asset_resolution: Optional[str] = None
    synthetic_asset_id: Optional[str] = None


@dataclass
class Dydx:
    markets: Optional[Dict[str, Market]] = None

# %%
response = requests.get("https://api.dydx.exchange/v3/markets")

# %%
response.json()
# Out:
# {'markets': {'CELO-USD': {'market': 'CELO-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'CELO',
#    'quoteAsset': 'USD',
#    'stepSize': '1',
#    'tickSize': '0.001',
#    'indexPrice': '0.4356',
#    'oraclePrice': '0.4347',
#    'priceChange24H': '0.010830',
#    'nextFundingRate': '-0.0000389571',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '10',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '242776.733000',
#    'trades24H': '232',
#    'openInterest': '190062',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '17700',
#    'maxPositionSize': '355000',
#    'baselinePositionSize': '35500',
#    'assetResolution': '1000000',
#    'syntheticAssetId': '0x43454c4f2d36000000000000000000'},
#   'LINK-USD': {'market': 'LINK-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'LINK',
#    'quoteAsset': 'USD',
#    'stepSize': '0.1',
#    'tickSize': '0.001',
#    'indexPrice': '6.1286',
#    'oraclePrice': '6.1281',
#    'priceChange24H': '-0.204016',
#    'nextFundingRate': '0.0000125000',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '1',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '3073667.274800',
#    'trades24H': '1337',
#    'openInterest': '491726.0',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '14000',
#    'maxPositionSize': '700000',
#    'baselinePositionSize': '70000',
#    'assetResolution': '10000000',
#    'syntheticAssetId': '0x4c494e4b2d37000000000000000000'},
#   'DOGE-USD': {'market': 'DOGE-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'DOGE',
#    'quoteAsset': 'USD',
#    'stepSize': '10',
#    'tickSize': '0.0001',
#    'indexPrice': '0.0843',
#    'oraclePrice': '0.0844',
#    'priceChange24H': '-0.003353',
#    'nextFundingRate': '0.0000059839',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '100',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '2627261.758000',
#    'trades24H': '1208',
#    'openInterest': '51559620',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '1400000',
#    'maxPositionSize': '70000000',
#    'baselinePositionSize': '7000000',
#    'assetResolution': '100000',
#    'syntheticAssetId': '0x444f47452d35000000000000000000'},
#   '1INCH-USD': {'market': '1INCH-USD',
#    'status': 'ONLINE',
#    'baseAsset': '1INCH',
#    'quoteAsset': 'USD',
#    'stepSize': '1',
#    'tickSize': '0.001',
#    'indexPrice': '0.5146',
#    'oraclePrice': '0.5136',
#    'priceChange24H': '-0.013299',
#    'nextFundingRate': '0.0000125000',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '10',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '550843.224000',
#    'trades24H': '531',
#    'openInterest': '1373577',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '70000',
#    'maxPositionSize': '3500000',
#    'baselinePositionSize': '350000',
#    'assetResolution': '10000000',
#    'syntheticAssetId': '0x31494e43482d370000000000000000'},
#   'XMR-USD': {'market': 'XMR-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'XMR',
#    'quoteAsset': 'USD',
#    'stepSize': '0.01',
#    'tickSize': '0.1',
#    'indexPrice': '132.1490',
#    'oraclePrice': '132.2796',
#    'priceChange24H': '2.964863',
#    'nextFundingRate': '0.0000056630',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '0.1',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '2035700.775000',
#    'trades24H': '899',
#    'openInterest': '4426.29',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '400',
#    'maxPositionSize': '20000',
#    'baselinePositionSize': '2000',
#    'assetResolution': '100000000',
#    'syntheticAssetId': '0x584d522d3800000000000000000000'},
#   'FIL-USD': {'market': 'FIL-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'FIL',
#    'quoteAsset': 'USD',
#    'stepSize': '0.1',
#    'tickSize': '0.01',
#    'indexPrice': '4.2725',
#    'oraclePrice': '4.2729',
#    'priceChange24H': '-0.117759',
#    'nextFundingRate': '0.0000125000',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '1',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '1077822.976000',
#    'trades24H': '902',
#    'openInterest': '91132.5',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '8000',
#    'maxPositionSize': '400000',
#    'baselinePositionSize': '40000',
#    'assetResolution': '10000000',
#    'syntheticAssetId': '0x46494c2d3700000000000000000000'},
#   'ETH-USD': {'market': 'ETH-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'ETH',
#    'quoteAsset': 'USD',
#    'stepSize': '0.001',
#    'tickSize': '0.1',
#    'indexPrice': '1190.2450',
#    'oraclePrice': '1188.3752',
#    'priceChange24H': '-41.545000',
#    'nextFundingRate': '-0.0000516956',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '0.01',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.05',
#    'maintenanceMarginFraction': '0.03',
#    'volume24H': '406386342.439000',
#    'trades24H': '77931',
#    'openInterest': '80655.731',
#    'incrementalInitialMarginFraction': '0.01',
#    'incrementalPositionSize': '100',
#    'maxPositionSize': '10000',
#    'baselinePositionSize': '500',
#    'assetResolution': '1000000000',
#    'syntheticAssetId': '0x4554482d3900000000000000000000'},
#   'AAVE-USD': {'market': 'AAVE-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'AAVE',
#    'quoteAsset': 'USD',
#    'stepSize': '0.01',
#    'tickSize': '0.01',
#    'indexPrice': '57.8976',
#    'oraclePrice': '57.8800',
#    'priceChange24H': '-1.552372',
#    'nextFundingRate': '0.0000125000',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '0.1',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '1315950.646700',
#    'trades24H': '2043',
#    'openInterest': '24770.21',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '1400',
#    'maxPositionSize': '70000',
#    'baselinePositionSize': '7000',
#    'assetResolution': '100000000',
#    'syntheticAssetId': '0x414156452d38000000000000000000'},
#   'ATOM-USD': {'market': 'ATOM-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'ATOM',
#    'quoteAsset': 'USD',
#    'stepSize': '0.1',
#    'tickSize': '0.001',
#    'indexPrice': '10.0277',
#    'oraclePrice': '10.0090',
#    'priceChange24H': '-0.273300',
#    'nextFundingRate': '-0.0000183969',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '1',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '1665879.412100',
#    'trades24H': '698',
#    'openInterest': '309625.4',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '14000',
#    'maxPositionSize': '700000',
#    'baselinePositionSize': '70000',
#    'assetResolution': '10000000',
#    'syntheticAssetId': '0x41544f4d2d37000000000000000000'},
#   'MKR-USD': {'market': 'MKR-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'MKR',
#    'quoteAsset': 'USD',
#    'stepSize': '0.001',
#    'tickSize': '1',
#    'indexPrice': '658.3357',
#    'oraclePrice': '658.5600',
#    'priceChange24H': '-36.038825',
#    'nextFundingRate': '-0.0000120711',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '0.01',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '1913111.131000',
#    'trades24H': '1966',
#    'openInterest': '2120.290',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '100',
#    'maxPositionSize': '5000',
#    'baselinePositionSize': '500',
#    'assetResolution': '1000000000',
#    'syntheticAssetId': '0x4d4b522d3900000000000000000000'},
#   'EOS-USD': {'market': 'EOS-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'EOS',
#    'quoteAsset': 'USD',
#    'stepSize': '1',
#    'tickSize': '0.001',
#    'indexPrice': '0.8881',
#    'oraclePrice': '0.8896',
#    'priceChange24H': '-0.034732',
#    'nextFundingRate': '0.0000125000',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '10',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '818817.122000',
#    'trades24H': '671',
#    'openInterest': '703548',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '50000',
#    'maxPositionSize': '2500000',
#    'baselinePositionSize': '250000',
#    'assetResolution': '1000000',
#    'syntheticAssetId': '0x454f532d3600000000000000000000'},
#   'COMP-USD': {'market': 'COMP-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'COMP',
#    'quoteAsset': 'USD',
#    'stepSize': '0.01',
#    'tickSize': '0.1',
#    'indexPrice': '40.1040',
#    'oraclePrice': '40.1675',
#    'priceChange24H': '-0.525308',
#    'nextFundingRate': '0.0000125000',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '0.1',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '940370.424000',
#    'trades24H': '846',
#    'openInterest': '15429.70',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '1200',
#    'maxPositionSize': '60000',
#    'baselinePositionSize': '6000',
#    'assetResolution': '100000000',
#    'syntheticAssetId': '0x434f4d502d38000000000000000000'},
#   'ALGO-USD': {'market': 'ALGO-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'ALGO',
#    'quoteAsset': 'USD',
#    'stepSize': '1',
#    'tickSize': '0.001',
#    'indexPrice': '0.2680',
#    'oraclePrice': '0.2675',
#    'priceChange24H': '-0.014432',
#    'nextFundingRate': '-0.0000317737',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '10',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '1893599.236000',
#    'trades24H': '1347',
#    'openInterest': '3851748',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '150000',
#    'maxPositionSize': '7500000',
#    'baselinePositionSize': '750000',
#    'assetResolution': '1000000',
#    'syntheticAssetId': '0x414c474f2d36000000000000000000'},
#   'XTZ-USD': {'market': 'XTZ-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'XTZ',
#    'quoteAsset': 'USD',
#    'stepSize': '1',
#    'tickSize': '0.001',
#    'indexPrice': '0.9712',
#    'oraclePrice': '0.9713',
#    'priceChange24H': '-0.042166',
#    'nextFundingRate': '0.0000125000',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '10',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '840924.824000',
#    'trades24H': '663',
#    'openInterest': '207592',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '19000',
#    'maxPositionSize': '970000',
#    'baselinePositionSize': '100000',
#    'assetResolution': '1000000',
#    'syntheticAssetId': '0x58545a2d3600000000000000000000'},
#   'UNI-USD': {'market': 'UNI-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'UNI',
#    'quoteAsset': 'USD',
#    'stepSize': '0.1',
#    'tickSize': '0.001',
#    'indexPrice': '5.8186',
#    'oraclePrice': '5.8140',
#    'priceChange24H': '-0.244434',
#    'nextFundingRate': '0.0000640260',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '1',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '4126451.310400',
#    'trades24H': '2636',
#    'openInterest': '380986.5',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '20000',
#    'maxPositionSize': '1000000',
#    'baselinePositionSize': '100000',
#    'assetResolution': '10000000',
#    'syntheticAssetId': '0x554e492d3700000000000000000000'},
#   'ADA-USD': {'market': 'ADA-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'ADA',
#    'quoteAsset': 'USD',
#    'stepSize': '1',
#    'tickSize': '0.001',
#    'indexPrice': '0.3228',
#    'oraclePrice': '0.3228',
#    'priceChange24H': '-0.012542',
#    'nextFundingRate': '-0.0000067356',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '10',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '4866748.220000',
#    'trades24H': '3848',
#    'openInterest': '13314525',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '200000',
#    'maxPositionSize': '10000000',
#    'baselinePositionSize': '1000000',
#    'assetResolution': '1000000',
#    'syntheticAssetId': '0x4144412d3600000000000000000000'},
#   'ZRX-USD': {'market': 'ZRX-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'ZRX',
#    'quoteAsset': 'USD',
#    'stepSize': '1',
#    'tickSize': '0.001',
#    'indexPrice': '0.1778',
#    'oraclePrice': '0.1779',
#    'priceChange24H': '-0.004610',
#    'nextFundingRate': '0.0000125000',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '10',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '1300214.898000',
#    'trades24H': '1272',
#    'openInterest': '3635694',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '170000',
#    'maxPositionSize': '8500000',
#    'baselinePositionSize': '850000',
#    'assetResolution': '1000000',
#    'syntheticAssetId': '0x5a52582d3600000000000000000000'},
#   'YFI-USD': {'market': 'YFI-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'YFI',
#    'quoteAsset': 'USD',
#    'stepSize': '0.0001',
#    'tickSize': '1',
#    'indexPrice': '6134.7612',
#    'oraclePrice': '6122.3981',
#    'priceChange24H': '-361.368774',
#    'nextFundingRate': '0.0000115800',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '0.001',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '889775.879500',
#    'trades24H': '850',
#    'openInterest': '161.5817',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '10',
#    'maxPositionSize': '500',
#    'baselinePositionSize': '50',
#    'assetResolution': '10000000000',
#    'syntheticAssetId': '0x5946492d3130000000000000000000'},
#   'MATIC-USD': {'market': 'MATIC-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'MATIC',
#    'quoteAsset': 'USD',
#    'stepSize': '1',
#    'tickSize': '0.0001',
#    'indexPrice': '0.8785',
#    'oraclePrice': '0.8756',
#    'priceChange24H': '-0.047587',
#    'nextFundingRate': '0.0000125000',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '10',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '20739476.273900',
#    'trades24H': '5995',
#    'openInterest': '10106328',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '200000',
#    'maxPositionSize': '10000000',
#    'baselinePositionSize': '1000000',
#    'assetResolution': '1000000',
#    'syntheticAssetId': '0x4d415449432d360000000000000000'},
#   'ETC-USD': {'market': 'ETC-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'ETC',
#    'quoteAsset': 'USD',
#    'stepSize': '0.1',
#    'tickSize': '0.01',
#    'indexPrice': '19.4865',
#    'oraclePrice': '19.4310',
#    'priceChange24H': '-0.714195',
#    'nextFundingRate': '-0.0000863254',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '1',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '2029732.790000',
#    'trades24H': '1038',
#    'openInterest': '109374.9',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '3000',
#    'maxPositionSize': '150000',
#    'baselinePositionSize': '15000',
#    'assetResolution': '10000000',
#    'syntheticAssetId': '0x4554432d3700000000000000000000'},
#   'AVAX-USD': {'market': 'AVAX-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'AVAX',
#    'quoteAsset': 'USD',
#    'stepSize': '0.1',
#    'tickSize': '0.01',
#    'indexPrice': '13.0106',
#    'oraclePrice': '13.0228',
#    'priceChange24H': '-0.247010',
#    'nextFundingRate': '-0.0001518506',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '1',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '2101865.209000',
#    'trades24H': '1300',
#    'openInterest': '212014.8',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '6000',
#    'maxPositionSize': '300000',
#    'baselinePositionSize': '30000',
#    'assetResolution': '10000000',
#    'syntheticAssetId': '0x415641582d37000000000000000000'},
#   'LTC-USD': {'market': 'LTC-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'LTC',
#    'quoteAsset': 'USD',
#    'stepSize': '0.01',
#    'tickSize': '0.1',
#    'indexPrice': '58.9145',
#    'oraclePrice': '58.9401',
#    'priceChange24H': '1.064492',
#    'nextFundingRate': '-0.0000000599',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '0.1',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '1141198.520000',
#    'trades24H': '602',
#    'openInterest': '19424.07',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '900',
#    'maxPositionSize': '45000',
#    'baselinePositionSize': '4500',
#    'assetResolution': '100000000',
#    'syntheticAssetId': '0x4c54432d3800000000000000000000'},
#   'ENJ-USD': {'market': 'ENJ-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'ENJ',
#    'quoteAsset': 'USD',
#    'stepSize': '1',
#    'tickSize': '0.001',
#    'indexPrice': '0.3051',
#    'oraclePrice': '0.3048',
#    'priceChange24H': '-0.018005',
#    'nextFundingRate': '-0.0000088569',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '10',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '573820.172000',
#    'trades24H': '482',
#    'openInterest': '964403',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '25000',
#    'maxPositionSize': '1200000',
#    'baselinePositionSize': '125000',
#    'assetResolution': '1000000',
#    'syntheticAssetId': '0x454e4a2d3600000000000000000000'},
#   'DOT-USD': {'market': 'DOT-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'DOT',
#    'quoteAsset': 'USD',
#    'stepSize': '0.1',
#    'tickSize': '0.01',
#    'indexPrice': '5.6235',
#    'oraclePrice': '5.6170',
#    'priceChange24H': '-0.223521',
#    'nextFundingRate': '0.0000050929',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '1',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '1040506.201000',
#    'trades24H': '442',
#    'openInterest': '335387.3',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '12000',
#    'maxPositionSize': '600000',
#    'baselinePositionSize': '60000',
#    'assetResolution': '10000000',
#    'syntheticAssetId': '0x444f542d3700000000000000000000'},
#   'LUNA-USD': {'market': 'LUNA-USD',
#    'status': 'CLOSE_ONLY',
#    'baseAsset': 'LUNA',
#    'quoteAsset': 'USD',
#    'stepSize': '0.01',
#    'tickSize': '0.0001',
#    'indexPrice': '0.0001',
#    'oraclePrice': '0.0001',
#    'priceChange24H': '0.000000',
#    'nextFundingRate': '0.0000000000',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '0.1',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '0.000500',
#    'trades24H': '1',
#    'openInterest': '354081.35',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '1000000',
#    'maxPositionSize': '2000000',
#    'baselinePositionSize': '1000',
#    'assetResolution': '1000000',
#    'syntheticAssetId': '0x4c554e412d36000000000000000000'},
#   'SNX-USD': {'market': 'SNX-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'SNX',
#    'quoteAsset': 'USD',
#    'stepSize': '0.1',
#    'tickSize': '0.01',
#    'indexPrice': '1.7666',
#    'oraclePrice': '1.7680',
#    'priceChange24H': '-0.007235',
#    'nextFundingRate': '0.0000125000',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '1',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.25',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '3601470.900000',
#    'trades24H': '1970',
#    'openInterest': '818016.9',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '30000',
#    'maxPositionSize': '1500000',
#    'baselinePositionSize': '150000',
#    'assetResolution': '10000000',
#    'syntheticAssetId': '0x534e582d3700000000000000000000'},
#   'RUNE-USD': {'market': 'RUNE-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'RUNE',
#    'quoteAsset': 'USD',
#    'stepSize': '1',
#    'tickSize': '0.001',
#    'indexPrice': '1.1763',
#    'oraclePrice': '1.1770',
#    'priceChange24H': '-0.035656',
#    'nextFundingRate': '0.0000018679',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '10',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '608473.802000',
#    'trades24H': '536',
#    'openInterest': '391917',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '20000',
#    'maxPositionSize': '1000000',
#    'baselinePositionSize': '100000',
#    'assetResolution': '1000000',
#    'syntheticAssetId': '0x52554e452d36000000000000000000'},
#   'XLM-USD': {'market': 'XLM-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'XLM',
#    'quoteAsset': 'USD',
#    'stepSize': '10',
#    'tickSize': '0.0001',
#    'indexPrice': '0.0893',
#    'oraclePrice': '0.0894',
#    'priceChange24H': '-0.002689',
#    'nextFundingRate': '0.0000125000',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '100',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '255698.802000',
#    'trades24H': '231',
#    'openInterest': '7668120',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '400000',
#    'maxPositionSize': '20000000',
#    'baselinePositionSize': '2000000',
#    'assetResolution': '100000',
#    'syntheticAssetId': '0x584c4d2d3500000000000000000000'},
#   'BCH-USD': {'market': 'BCH-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'BCH',
#    'quoteAsset': 'USD',
#    'stepSize': '0.01',
#    'tickSize': '0.1',
#    'indexPrice': '101.9056',
#    'oraclePrice': '101.8200',
#    'priceChange24H': '-2.556242',
#    'nextFundingRate': '-0.0000864158',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '0.1',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '666016.404000',
#    'trades24H': '325',
#    'openInterest': '8071.99',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '400',
#    'maxPositionSize': '20000',
#    'baselinePositionSize': '2000',
#    'assetResolution': '100000000',
#    'syntheticAssetId': '0x4243482d3800000000000000000000'},
#   'TRX-USD': {'market': 'TRX-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'TRX',
#    'quoteAsset': 'USD',
#    'stepSize': '10',
#    'tickSize': '0.0001',
#    'indexPrice': '0.0493',
#    'oraclePrice': '0.0493',
#    'priceChange24H': '-0.001352',
#    'nextFundingRate': '-0.0000401715',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '100',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '2116929.944000',
#    'trades24H': '1116',
#    'openInterest': '20131900',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '700000',
#    'maxPositionSize': '35000000',
#    'baselinePositionSize': '3500000',
#    'assetResolution': '10000',
#    'syntheticAssetId': '0x5452582d3400000000000000000000'},
#   'BTC-USD': {'market': 'BTC-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'BTC',
#    'quoteAsset': 'USD',
#    'stepSize': '0.0001',
#    'tickSize': '1',
#    'indexPrice': '16506.4000',
#    'oraclePrice': '16505.7500',
#    'priceChange24H': '-231.216000',
#    'nextFundingRate': '-0.0000777201',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '0.001',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.05',
#    'maintenanceMarginFraction': '0.03',
#    'volume24H': '213529872.491100',
#    'trades24H': '38009',
#    'openInterest': '3721.1035',
#    'incrementalInitialMarginFraction': '0.01',
#    'incrementalPositionSize': '5',
#    'maxPositionSize': '500',
#    'baselinePositionSize': '25',
#    'assetResolution': '10000000000',
#    'syntheticAssetId': '0x4254432d3130000000000000000000'},
#   'UMA-USD': {'market': 'UMA-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'UMA',
#    'quoteAsset': 'USD',
#    'stepSize': '0.1',
#    'tickSize': '0.01',
#    'indexPrice': '1.6514',
#    'oraclePrice': '1.6542',
#    'priceChange24H': '-0.031177',
#    'nextFundingRate': '-0.0000343862',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '1',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '1.0',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '52856.865000',
#    'trades24H': '163',
#    'openInterest': '113809.2',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '1000',
#    'maxPositionSize': '30000',
#    'baselinePositionSize': '2000',
#    'assetResolution': '10000000',
#    'syntheticAssetId': '0x554d412d3700000000000000000000'},
#   'NEAR-USD': {'market': 'NEAR-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'NEAR',
#    'quoteAsset': 'USD',
#    'stepSize': '0.1',
#    'tickSize': '0.01',
#    'indexPrice': '1.8523',
#    'oraclePrice': '1.8477',
#    'priceChange24H': '-0.114106',
#    'nextFundingRate': '0.0000125000',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '1',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '4959246.094000',
#    'trades24H': '2511',
#    'openInterest': '652258.3',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '14000',
#    'maxPositionSize': '700000',
#    'baselinePositionSize': '70000',
#    'assetResolution': '1000000',
#    'syntheticAssetId': '0x4e4541522d36000000000000000000'},
#   'ZEC-USD': {'market': 'ZEC-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'ZEC',
#    'quoteAsset': 'USD',
#    'stepSize': '0.01',
#    'tickSize': '0.1',
#    'indexPrice': '38.5100',
#    'oraclePrice': '38.5000',
#    'priceChange24H': '-1.520000',
#    'nextFundingRate': '0.0000125000',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '0.1',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '990406.241000',
#    'trades24H': '1900',
#    'openInterest': '14476.36',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '700',
#    'maxPositionSize': '35000',
#    'baselinePositionSize': '3500',
#    'assetResolution': '100000000',
#    'syntheticAssetId': '0x5a45432d3800000000000000000000'},
#   'SOL-USD': {'market': 'SOL-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'SOL',
#    'quoteAsset': 'USD',
#    'stepSize': '0.1',
#    'tickSize': '0.001',
#    'indexPrice': '14.0991',
#    'oraclePrice': '14.1123',
#    'priceChange24H': '-0.100891',
#    'nextFundingRate': '-0.0000248822',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '1',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.50',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '6616679.940100',
#    'trades24H': '7221',
#    'openInterest': '430694.3',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '3000',
#    'maxPositionSize': '150000',
#    'baselinePositionSize': '15000',
#    'assetResolution': '10000000',
#    'syntheticAssetId': '0x534f4c2d3700000000000000000000'},
#   'SUSHI-USD': {'market': 'SUSHI-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'SUSHI',
#    'quoteAsset': 'USD',
#    'stepSize': '0.1',
#    'tickSize': '0.001',
#    'indexPrice': '1.2682',
#    'oraclePrice': '1.2660',
#    'priceChange24H': '-0.064752',
#    'nextFundingRate': '0.0000084246',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '1',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '3478454.729800',
#    'trades24H': '1584',
#    'openInterest': '1127615.6',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '40000',
#    'maxPositionSize': '2000000',
#    'baselinePositionSize': '200000',
#    'assetResolution': '10000000',
#    'syntheticAssetId': '0x53555348492d370000000000000000'},
#   'ICP-USD': {'market': 'ICP-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'ICP',
#    'quoteAsset': 'USD',
#    'stepSize': '0.1',
#    'tickSize': '0.01',
#    'indexPrice': '3.8399',
#    'oraclePrice': '3.8322',
#    'priceChange24H': '-0.082492',
#    'nextFundingRate': '0.0000031212',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '1',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '553759.452000',
#    'trades24H': '568',
#    'openInterest': '109608.9',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '2900',
#    'maxPositionSize': '58000',
#    'baselinePositionSize': '5800',
#    'assetResolution': '10000000',
#    'syntheticAssetId': '0x4943502d3700000000000000000000'},
#   'CRV-USD': {'market': 'CRV-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'CRV',
#    'quoteAsset': 'USD',
#    'stepSize': '1',
#    'tickSize': '0.0001',
#    'indexPrice': '0.5420',
#    'oraclePrice': '0.5415',
#    'priceChange24H': '-0.056141',
#    'nextFundingRate': '-0.0000144926',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '10',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '1917133.329600',
#    'trades24H': '1750',
#    'openInterest': '1977801',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '130000',
#    'maxPositionSize': '6500000',
#    'baselinePositionSize': '650000',
#    'assetResolution': '1000000',
#    'syntheticAssetId': '0x4352562d3600000000000000000000'}}}

# %%
data = response.json()

# %%
data
# Out:
# {'markets': {'CELO-USD': {'market': 'CELO-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'CELO',
#    'quoteAsset': 'USD',
#    'stepSize': '1',
#    'tickSize': '0.001',
#    'indexPrice': '0.4356',
#    'oraclePrice': '0.4347',
#    'priceChange24H': '0.010830',
#    'nextFundingRate': '-0.0000389571',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '10',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '242776.733000',
#    'trades24H': '232',
#    'openInterest': '190062',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '17700',
#    'maxPositionSize': '355000',
#    'baselinePositionSize': '35500',
#    'assetResolution': '1000000',
#    'syntheticAssetId': '0x43454c4f2d36000000000000000000'},
#   'LINK-USD': {'market': 'LINK-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'LINK',
#    'quoteAsset': 'USD',
#    'stepSize': '0.1',
#    'tickSize': '0.001',
#    'indexPrice': '6.1286',
#    'oraclePrice': '6.1281',
#    'priceChange24H': '-0.204016',
#    'nextFundingRate': '0.0000125000',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '1',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '3073667.274800',
#    'trades24H': '1337',
#    'openInterest': '491726.0',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '14000',
#    'maxPositionSize': '700000',
#    'baselinePositionSize': '70000',
#    'assetResolution': '10000000',
#    'syntheticAssetId': '0x4c494e4b2d37000000000000000000'},
#   'DOGE-USD': {'market': 'DOGE-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'DOGE',
#    'quoteAsset': 'USD',
#    'stepSize': '10',
#    'tickSize': '0.0001',
#    'indexPrice': '0.0843',
#    'oraclePrice': '0.0844',
#    'priceChange24H': '-0.003353',
#    'nextFundingRate': '0.0000059839',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '100',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '2627261.758000',
#    'trades24H': '1208',
#    'openInterest': '51559620',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '1400000',
#    'maxPositionSize': '70000000',
#    'baselinePositionSize': '7000000',
#    'assetResolution': '100000',
#    'syntheticAssetId': '0x444f47452d35000000000000000000'},
#   '1INCH-USD': {'market': '1INCH-USD',
#    'status': 'ONLINE',
#    'baseAsset': '1INCH',
#    'quoteAsset': 'USD',
#    'stepSize': '1',
#    'tickSize': '0.001',
#    'indexPrice': '0.5146',
#    'oraclePrice': '0.5136',
#    'priceChange24H': '-0.013299',
#    'nextFundingRate': '0.0000125000',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '10',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '550843.224000',
#    'trades24H': '531',
#    'openInterest': '1373577',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '70000',
#    'maxPositionSize': '3500000',
#    'baselinePositionSize': '350000',
#    'assetResolution': '10000000',
#    'syntheticAssetId': '0x31494e43482d370000000000000000'},
#   'XMR-USD': {'market': 'XMR-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'XMR',
#    'quoteAsset': 'USD',
#    'stepSize': '0.01',
#    'tickSize': '0.1',
#    'indexPrice': '132.1490',
#    'oraclePrice': '132.2796',
#    'priceChange24H': '2.964863',
#    'nextFundingRate': '0.0000056630',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '0.1',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '2035700.775000',
#    'trades24H': '899',
#    'openInterest': '4426.29',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '400',
#    'maxPositionSize': '20000',
#    'baselinePositionSize': '2000',
#    'assetResolution': '100000000',
#    'syntheticAssetId': '0x584d522d3800000000000000000000'},
#   'FIL-USD': {'market': 'FIL-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'FIL',
#    'quoteAsset': 'USD',
#    'stepSize': '0.1',
#    'tickSize': '0.01',
#    'indexPrice': '4.2725',
#    'oraclePrice': '4.2729',
#    'priceChange24H': '-0.117759',
#    'nextFundingRate': '0.0000125000',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '1',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '1077822.976000',
#    'trades24H': '902',
#    'openInterest': '91132.5',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '8000',
#    'maxPositionSize': '400000',
#    'baselinePositionSize': '40000',
#    'assetResolution': '10000000',
#    'syntheticAssetId': '0x46494c2d3700000000000000000000'},
#   'ETH-USD': {'market': 'ETH-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'ETH',
#    'quoteAsset': 'USD',
#    'stepSize': '0.001',
#    'tickSize': '0.1',
#    'indexPrice': '1190.2450',
#    'oraclePrice': '1188.3752',
#    'priceChange24H': '-41.545000',
#    'nextFundingRate': '-0.0000516956',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '0.01',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.05',
#    'maintenanceMarginFraction': '0.03',
#    'volume24H': '406386342.439000',
#    'trades24H': '77931',
#    'openInterest': '80655.731',
#    'incrementalInitialMarginFraction': '0.01',
#    'incrementalPositionSize': '100',
#    'maxPositionSize': '10000',
#    'baselinePositionSize': '500',
#    'assetResolution': '1000000000',
#    'syntheticAssetId': '0x4554482d3900000000000000000000'},
#   'AAVE-USD': {'market': 'AAVE-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'AAVE',
#    'quoteAsset': 'USD',
#    'stepSize': '0.01',
#    'tickSize': '0.01',
#    'indexPrice': '57.8976',
#    'oraclePrice': '57.8800',
#    'priceChange24H': '-1.552372',
#    'nextFundingRate': '0.0000125000',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '0.1',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '1315950.646700',
#    'trades24H': '2043',
#    'openInterest': '24770.21',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '1400',
#    'maxPositionSize': '70000',
#    'baselinePositionSize': '7000',
#    'assetResolution': '100000000',
#    'syntheticAssetId': '0x414156452d38000000000000000000'},
#   'ATOM-USD': {'market': 'ATOM-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'ATOM',
#    'quoteAsset': 'USD',
#    'stepSize': '0.1',
#    'tickSize': '0.001',
#    'indexPrice': '10.0277',
#    'oraclePrice': '10.0090',
#    'priceChange24H': '-0.273300',
#    'nextFundingRate': '-0.0000183969',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '1',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '1665879.412100',
#    'trades24H': '698',
#    'openInterest': '309625.4',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '14000',
#    'maxPositionSize': '700000',
#    'baselinePositionSize': '70000',
#    'assetResolution': '10000000',
#    'syntheticAssetId': '0x41544f4d2d37000000000000000000'},
#   'MKR-USD': {'market': 'MKR-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'MKR',
#    'quoteAsset': 'USD',
#    'stepSize': '0.001',
#    'tickSize': '1',
#    'indexPrice': '658.3357',
#    'oraclePrice': '658.5600',
#    'priceChange24H': '-36.038825',
#    'nextFundingRate': '-0.0000120711',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '0.01',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '1913111.131000',
#    'trades24H': '1966',
#    'openInterest': '2120.290',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '100',
#    'maxPositionSize': '5000',
#    'baselinePositionSize': '500',
#    'assetResolution': '1000000000',
#    'syntheticAssetId': '0x4d4b522d3900000000000000000000'},
#   'EOS-USD': {'market': 'EOS-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'EOS',
#    'quoteAsset': 'USD',
#    'stepSize': '1',
#    'tickSize': '0.001',
#    'indexPrice': '0.8881',
#    'oraclePrice': '0.8896',
#    'priceChange24H': '-0.034732',
#    'nextFundingRate': '0.0000125000',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '10',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '818817.122000',
#    'trades24H': '671',
#    'openInterest': '703548',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '50000',
#    'maxPositionSize': '2500000',
#    'baselinePositionSize': '250000',
#    'assetResolution': '1000000',
#    'syntheticAssetId': '0x454f532d3600000000000000000000'},
#   'COMP-USD': {'market': 'COMP-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'COMP',
#    'quoteAsset': 'USD',
#    'stepSize': '0.01',
#    'tickSize': '0.1',
#    'indexPrice': '40.1040',
#    'oraclePrice': '40.1675',
#    'priceChange24H': '-0.525308',
#    'nextFundingRate': '0.0000125000',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '0.1',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '940370.424000',
#    'trades24H': '846',
#    'openInterest': '15429.70',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '1200',
#    'maxPositionSize': '60000',
#    'baselinePositionSize': '6000',
#    'assetResolution': '100000000',
#    'syntheticAssetId': '0x434f4d502d38000000000000000000'},
#   'ALGO-USD': {'market': 'ALGO-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'ALGO',
#    'quoteAsset': 'USD',
#    'stepSize': '1',
#    'tickSize': '0.001',
#    'indexPrice': '0.2680',
#    'oraclePrice': '0.2675',
#    'priceChange24H': '-0.014432',
#    'nextFundingRate': '-0.0000317737',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '10',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '1893599.236000',
#    'trades24H': '1347',
#    'openInterest': '3851748',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '150000',
#    'maxPositionSize': '7500000',
#    'baselinePositionSize': '750000',
#    'assetResolution': '1000000',
#    'syntheticAssetId': '0x414c474f2d36000000000000000000'},
#   'XTZ-USD': {'market': 'XTZ-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'XTZ',
#    'quoteAsset': 'USD',
#    'stepSize': '1',
#    'tickSize': '0.001',
#    'indexPrice': '0.9712',
#    'oraclePrice': '0.9713',
#    'priceChange24H': '-0.042166',
#    'nextFundingRate': '0.0000125000',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '10',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '840924.824000',
#    'trades24H': '663',
#    'openInterest': '207592',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '19000',
#    'maxPositionSize': '970000',
#    'baselinePositionSize': '100000',
#    'assetResolution': '1000000',
#    'syntheticAssetId': '0x58545a2d3600000000000000000000'},
#   'UNI-USD': {'market': 'UNI-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'UNI',
#    'quoteAsset': 'USD',
#    'stepSize': '0.1',
#    'tickSize': '0.001',
#    'indexPrice': '5.8186',
#    'oraclePrice': '5.8140',
#    'priceChange24H': '-0.244434',
#    'nextFundingRate': '0.0000640260',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '1',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '4126451.310400',
#    'trades24H': '2636',
#    'openInterest': '380986.5',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '20000',
#    'maxPositionSize': '1000000',
#    'baselinePositionSize': '100000',
#    'assetResolution': '10000000',
#    'syntheticAssetId': '0x554e492d3700000000000000000000'},
#   'ADA-USD': {'market': 'ADA-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'ADA',
#    'quoteAsset': 'USD',
#    'stepSize': '1',
#    'tickSize': '0.001',
#    'indexPrice': '0.3228',
#    'oraclePrice': '0.3228',
#    'priceChange24H': '-0.012542',
#    'nextFundingRate': '-0.0000067356',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '10',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '4866748.220000',
#    'trades24H': '3848',
#    'openInterest': '13314525',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '200000',
#    'maxPositionSize': '10000000',
#    'baselinePositionSize': '1000000',
#    'assetResolution': '1000000',
#    'syntheticAssetId': '0x4144412d3600000000000000000000'},
#   'ZRX-USD': {'market': 'ZRX-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'ZRX',
#    'quoteAsset': 'USD',
#    'stepSize': '1',
#    'tickSize': '0.001',
#    'indexPrice': '0.1778',
#    'oraclePrice': '0.1779',
#    'priceChange24H': '-0.004610',
#    'nextFundingRate': '0.0000125000',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '10',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '1300214.898000',
#    'trades24H': '1272',
#    'openInterest': '3635694',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '170000',
#    'maxPositionSize': '8500000',
#    'baselinePositionSize': '850000',
#    'assetResolution': '1000000',
#    'syntheticAssetId': '0x5a52582d3600000000000000000000'},
#   'YFI-USD': {'market': 'YFI-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'YFI',
#    'quoteAsset': 'USD',
#    'stepSize': '0.0001',
#    'tickSize': '1',
#    'indexPrice': '6134.7612',
#    'oraclePrice': '6122.3981',
#    'priceChange24H': '-361.368774',
#    'nextFundingRate': '0.0000115800',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '0.001',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '889775.879500',
#    'trades24H': '850',
#    'openInterest': '161.5817',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '10',
#    'maxPositionSize': '500',
#    'baselinePositionSize': '50',
#    'assetResolution': '10000000000',
#    'syntheticAssetId': '0x5946492d3130000000000000000000'},
#   'MATIC-USD': {'market': 'MATIC-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'MATIC',
#    'quoteAsset': 'USD',
#    'stepSize': '1',
#    'tickSize': '0.0001',
#    'indexPrice': '0.8785',
#    'oraclePrice': '0.8756',
#    'priceChange24H': '-0.047587',
#    'nextFundingRate': '0.0000125000',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '10',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '20739476.273900',
#    'trades24H': '5995',
#    'openInterest': '10106328',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '200000',
#    'maxPositionSize': '10000000',
#    'baselinePositionSize': '1000000',
#    'assetResolution': '1000000',
#    'syntheticAssetId': '0x4d415449432d360000000000000000'},
#   'ETC-USD': {'market': 'ETC-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'ETC',
#    'quoteAsset': 'USD',
#    'stepSize': '0.1',
#    'tickSize': '0.01',
#    'indexPrice': '19.4865',
#    'oraclePrice': '19.4310',
#    'priceChange24H': '-0.714195',
#    'nextFundingRate': '-0.0000863254',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '1',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '2029732.790000',
#    'trades24H': '1038',
#    'openInterest': '109374.9',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '3000',
#    'maxPositionSize': '150000',
#    'baselinePositionSize': '15000',
#    'assetResolution': '10000000',
#    'syntheticAssetId': '0x4554432d3700000000000000000000'},
#   'AVAX-USD': {'market': 'AVAX-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'AVAX',
#    'quoteAsset': 'USD',
#    'stepSize': '0.1',
#    'tickSize': '0.01',
#    'indexPrice': '13.0106',
#    'oraclePrice': '13.0228',
#    'priceChange24H': '-0.247010',
#    'nextFundingRate': '-0.0001518506',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '1',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '2101865.209000',
#    'trades24H': '1300',
#    'openInterest': '212014.8',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '6000',
#    'maxPositionSize': '300000',
#    'baselinePositionSize': '30000',
#    'assetResolution': '10000000',
#    'syntheticAssetId': '0x415641582d37000000000000000000'},
#   'LTC-USD': {'market': 'LTC-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'LTC',
#    'quoteAsset': 'USD',
#    'stepSize': '0.01',
#    'tickSize': '0.1',
#    'indexPrice': '58.9145',
#    'oraclePrice': '58.9401',
#    'priceChange24H': '1.064492',
#    'nextFundingRate': '-0.0000000599',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '0.1',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '1141198.520000',
#    'trades24H': '602',
#    'openInterest': '19424.07',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '900',
#    'maxPositionSize': '45000',
#    'baselinePositionSize': '4500',
#    'assetResolution': '100000000',
#    'syntheticAssetId': '0x4c54432d3800000000000000000000'},
#   'ENJ-USD': {'market': 'ENJ-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'ENJ',
#    'quoteAsset': 'USD',
#    'stepSize': '1',
#    'tickSize': '0.001',
#    'indexPrice': '0.3051',
#    'oraclePrice': '0.3048',
#    'priceChange24H': '-0.018005',
#    'nextFundingRate': '-0.0000088569',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '10',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '573820.172000',
#    'trades24H': '482',
#    'openInterest': '964403',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '25000',
#    'maxPositionSize': '1200000',
#    'baselinePositionSize': '125000',
#    'assetResolution': '1000000',
#    'syntheticAssetId': '0x454e4a2d3600000000000000000000'},
#   'DOT-USD': {'market': 'DOT-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'DOT',
#    'quoteAsset': 'USD',
#    'stepSize': '0.1',
#    'tickSize': '0.01',
#    'indexPrice': '5.6235',
#    'oraclePrice': '5.6170',
#    'priceChange24H': '-0.223521',
#    'nextFundingRate': '0.0000050929',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '1',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '1040506.201000',
#    'trades24H': '442',
#    'openInterest': '335387.3',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '12000',
#    'maxPositionSize': '600000',
#    'baselinePositionSize': '60000',
#    'assetResolution': '10000000',
#    'syntheticAssetId': '0x444f542d3700000000000000000000'},
#   'LUNA-USD': {'market': 'LUNA-USD',
#    'status': 'CLOSE_ONLY',
#    'baseAsset': 'LUNA',
#    'quoteAsset': 'USD',
#    'stepSize': '0.01',
#    'tickSize': '0.0001',
#    'indexPrice': '0.0001',
#    'oraclePrice': '0.0001',
#    'priceChange24H': '0.000000',
#    'nextFundingRate': '0.0000000000',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '0.1',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '0.000500',
#    'trades24H': '1',
#    'openInterest': '354081.35',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '1000000',
#    'maxPositionSize': '2000000',
#    'baselinePositionSize': '1000',
#    'assetResolution': '1000000',
#    'syntheticAssetId': '0x4c554e412d36000000000000000000'},
#   'SNX-USD': {'market': 'SNX-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'SNX',
#    'quoteAsset': 'USD',
#    'stepSize': '0.1',
#    'tickSize': '0.01',
#    'indexPrice': '1.7666',
#    'oraclePrice': '1.7680',
#    'priceChange24H': '-0.007235',
#    'nextFundingRate': '0.0000125000',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '1',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.25',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '3601470.900000',
#    'trades24H': '1970',
#    'openInterest': '818016.9',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '30000',
#    'maxPositionSize': '1500000',
#    'baselinePositionSize': '150000',
#    'assetResolution': '10000000',
#    'syntheticAssetId': '0x534e582d3700000000000000000000'},
#   'RUNE-USD': {'market': 'RUNE-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'RUNE',
#    'quoteAsset': 'USD',
#    'stepSize': '1',
#    'tickSize': '0.001',
#    'indexPrice': '1.1763',
#    'oraclePrice': '1.1770',
#    'priceChange24H': '-0.035656',
#    'nextFundingRate': '0.0000018679',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '10',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '608473.802000',
#    'trades24H': '536',
#    'openInterest': '391917',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '20000',
#    'maxPositionSize': '1000000',
#    'baselinePositionSize': '100000',
#    'assetResolution': '1000000',
#    'syntheticAssetId': '0x52554e452d36000000000000000000'},
#   'XLM-USD': {'market': 'XLM-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'XLM',
#    'quoteAsset': 'USD',
#    'stepSize': '10',
#    'tickSize': '0.0001',
#    'indexPrice': '0.0893',
#    'oraclePrice': '0.0894',
#    'priceChange24H': '-0.002689',
#    'nextFundingRate': '0.0000125000',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '100',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '255698.802000',
#    'trades24H': '231',
#    'openInterest': '7668120',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '400000',
#    'maxPositionSize': '20000000',
#    'baselinePositionSize': '2000000',
#    'assetResolution': '100000',
#    'syntheticAssetId': '0x584c4d2d3500000000000000000000'},
#   'BCH-USD': {'market': 'BCH-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'BCH',
#    'quoteAsset': 'USD',
#    'stepSize': '0.01',
#    'tickSize': '0.1',
#    'indexPrice': '101.9056',
#    'oraclePrice': '101.8200',
#    'priceChange24H': '-2.556242',
#    'nextFundingRate': '-0.0000864158',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '0.1',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '666016.404000',
#    'trades24H': '325',
#    'openInterest': '8071.99',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '400',
#    'maxPositionSize': '20000',
#    'baselinePositionSize': '2000',
#    'assetResolution': '100000000',
#    'syntheticAssetId': '0x4243482d3800000000000000000000'},
#   'TRX-USD': {'market': 'TRX-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'TRX',
#    'quoteAsset': 'USD',
#    'stepSize': '10',
#    'tickSize': '0.0001',
#    'indexPrice': '0.0493',
#    'oraclePrice': '0.0493',
#    'priceChange24H': '-0.001352',
#    'nextFundingRate': '-0.0000401715',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '100',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '2116929.944000',
#    'trades24H': '1116',
#    'openInterest': '20131900',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '700000',
#    'maxPositionSize': '35000000',
#    'baselinePositionSize': '3500000',
#    'assetResolution': '10000',
#    'syntheticAssetId': '0x5452582d3400000000000000000000'},
#   'BTC-USD': {'market': 'BTC-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'BTC',
#    'quoteAsset': 'USD',
#    'stepSize': '0.0001',
#    'tickSize': '1',
#    'indexPrice': '16506.4000',
#    'oraclePrice': '16505.7500',
#    'priceChange24H': '-231.216000',
#    'nextFundingRate': '-0.0000777201',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '0.001',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.05',
#    'maintenanceMarginFraction': '0.03',
#    'volume24H': '213529872.491100',
#    'trades24H': '38009',
#    'openInterest': '3721.1035',
#    'incrementalInitialMarginFraction': '0.01',
#    'incrementalPositionSize': '5',
#    'maxPositionSize': '500',
#    'baselinePositionSize': '25',
#    'assetResolution': '10000000000',
#    'syntheticAssetId': '0x4254432d3130000000000000000000'},
#   'UMA-USD': {'market': 'UMA-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'UMA',
#    'quoteAsset': 'USD',
#    'stepSize': '0.1',
#    'tickSize': '0.01',
#    'indexPrice': '1.6514',
#    'oraclePrice': '1.6542',
#    'priceChange24H': '-0.031177',
#    'nextFundingRate': '-0.0000343862',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '1',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '1.0',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '52856.865000',
#    'trades24H': '163',
#    'openInterest': '113809.2',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '1000',
#    'maxPositionSize': '30000',
#    'baselinePositionSize': '2000',
#    'assetResolution': '10000000',
#    'syntheticAssetId': '0x554d412d3700000000000000000000'},
#   'NEAR-USD': {'market': 'NEAR-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'NEAR',
#    'quoteAsset': 'USD',
#    'stepSize': '0.1',
#    'tickSize': '0.01',
#    'indexPrice': '1.8523',
#    'oraclePrice': '1.8477',
#    'priceChange24H': '-0.114106',
#    'nextFundingRate': '0.0000125000',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '1',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '4959246.094000',
#    'trades24H': '2511',
#    'openInterest': '652258.3',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '14000',
#    'maxPositionSize': '700000',
#    'baselinePositionSize': '70000',
#    'assetResolution': '1000000',
#    'syntheticAssetId': '0x4e4541522d36000000000000000000'},
#   'ZEC-USD': {'market': 'ZEC-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'ZEC',
#    'quoteAsset': 'USD',
#    'stepSize': '0.01',
#    'tickSize': '0.1',
#    'indexPrice': '38.5100',
#    'oraclePrice': '38.5000',
#    'priceChange24H': '-1.520000',
#    'nextFundingRate': '0.0000125000',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '0.1',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '990406.241000',
#    'trades24H': '1900',
#    'openInterest': '14476.36',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '700',
#    'maxPositionSize': '35000',
#    'baselinePositionSize': '3500',
#    'assetResolution': '100000000',
#    'syntheticAssetId': '0x5a45432d3800000000000000000000'},
#   'SOL-USD': {'market': 'SOL-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'SOL',
#    'quoteAsset': 'USD',
#    'stepSize': '0.1',
#    'tickSize': '0.001',
#    'indexPrice': '14.0991',
#    'oraclePrice': '14.1123',
#    'priceChange24H': '-0.100891',
#    'nextFundingRate': '-0.0000248822',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '1',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.50',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '6616679.940100',
#    'trades24H': '7221',
#    'openInterest': '430694.3',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '3000',
#    'maxPositionSize': '150000',
#    'baselinePositionSize': '15000',
#    'assetResolution': '10000000',
#    'syntheticAssetId': '0x534f4c2d3700000000000000000000'},
#   'SUSHI-USD': {'market': 'SUSHI-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'SUSHI',
#    'quoteAsset': 'USD',
#    'stepSize': '0.1',
#    'tickSize': '0.001',
#    'indexPrice': '1.2682',
#    'oraclePrice': '1.2660',
#    'priceChange24H': '-0.064752',
#    'nextFundingRate': '0.0000084246',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '1',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '3478454.729800',
#    'trades24H': '1584',
#    'openInterest': '1127615.6',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '40000',
#    'maxPositionSize': '2000000',
#    'baselinePositionSize': '200000',
#    'assetResolution': '10000000',
#    'syntheticAssetId': '0x53555348492d370000000000000000'},
#   'ICP-USD': {'market': 'ICP-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'ICP',
#    'quoteAsset': 'USD',
#    'stepSize': '0.1',
#    'tickSize': '0.01',
#    'indexPrice': '3.8399',
#    'oraclePrice': '3.8322',
#    'priceChange24H': '-0.082492',
#    'nextFundingRate': '0.0000031212',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '1',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '553759.452000',
#    'trades24H': '568',
#    'openInterest': '109608.9',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '2900',
#    'maxPositionSize': '58000',
#    'baselinePositionSize': '5800',
#    'assetResolution': '10000000',
#    'syntheticAssetId': '0x4943502d3700000000000000000000'},
#   'CRV-USD': {'market': 'CRV-USD',
#    'status': 'ONLINE',
#    'baseAsset': 'CRV',
#    'quoteAsset': 'USD',
#    'stepSize': '1',
#    'tickSize': '0.0001',
#    'indexPrice': '0.5420',
#    'oraclePrice': '0.5415',
#    'priceChange24H': '-0.056141',
#    'nextFundingRate': '-0.0000144926',
#    'nextFundingAt': '2022-11-17T11:00:00.000Z',
#    'minOrderSize': '10',
#    'type': 'PERPETUAL',
#    'initialMarginFraction': '0.10',
#    'maintenanceMarginFraction': '0.05',
#    'volume24H': '1917133.329600',
#    'trades24H': '1750',
#    'openInterest': '1977801',
#    'incrementalInitialMarginFraction': '0.02',
#    'incrementalPositionSize': '130000',
#    'maxPositionSize': '6500000',
#    'baselinePositionSize': '650000',
#    'assetResolution': '1000000',
#    'syntheticAssetId': '0x4352562d3600000000000000000000'}}}
